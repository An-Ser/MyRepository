# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
class SalesReport():  
    # Наш новый метод внутри класса.  
    # Мы определяем его похожим образом с обычными функциями,  
    #   но только помещаем внутрь класса и первым аргументом передаём self  
    def print_report(self):  
        print("Total amount:", self.amount)  
          
          
# Дальше мы применяем report так же, как и в примере выше   
report = SalesReport()  
report.amount = 10  
  
report_2 = SalesReport()  
report_2.amount = 20  
  
# Используем наши новые методы  
report.print_report()# => Total amount: 10  
report_2.print_report() # => Total amount: 20
# Out:
# Total amount: 10
# Total amount: 20

# %%
import numpy as np
class DepartmentReport():  
    # Позволим добавлять много разных сделок   
    def add_revenue(self, amount):   
        # На первой сделке создадим список для хранения всех сделок   
        if not hasattr(self, 'revenues'):  
            self.revenues = []  
        # Добавим текущую сделку  
        self.revenues.append(amount)  
          
    # Посчитаем сумму всех сделок      
    def average_revenue(self):  
        return np.mean(self.revenues)  



report = DepartmentReport()
report.add_revenue(1000000)
report.add_revenue(400000)
print(report.revenues)
# => [1000000, 400000]
print(report.average_revenue())
# => 700000.0
# Out:
# [1000000, 400000]
# 700000.0

# %%
x = {'a' : 1, 'b' : 2, 'c': 3}
y = {t for t in x if t != 'a'}
z = {key:x[key] for key in x.keys() & y}
print(sum(z.values()))
print(y)
print(z)

a=[1,2,3]
del a[::-1]
print(a)
# Out:
# 5
# {'b', 'c'}
# {'b': 2, 'c': 3}
# []

# %%
display(sber_data.tail())
# Out:
#           id  full_sq  life_sq  floor              sub_area  preschool_quota  \
# 30466  30469       44     27.0    7.0              Otradnoe           5088.0
# 30467  30470       86     59.0    3.0              Tverskoe           1874.0
# 30468  30471       45      NaN   10.0  Poselenie Vnukovskoe              NaN
# 30469  30472       64     32.0    5.0          Obruchevskoe           2372.0
# 30470  30473       43     28.0    1.0           Novogireevo           2215.0
#
#        preschool_education_centers_raion  school_quota  \
# 30466                                  4       12721.0
# 30467                                  4        6772.0
# 30468                                  0           NaN
# 30469                                  6        6083.0
# 30470                                  4        5824.0
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 30466                               4                                      0
# 30467                               4                                      1
# 30468                               0                                      0
# 30469                               8                                      0
# 30470                               4                                      0
#
#        ...  office_km  additional_education_km  preschool_km  big_church_km  \
# 30466  ...   1.103579                 0.167718      0.349899       1.235066
# 30467  ...   0.069986                 0.086552      0.362681       0.850385
# 30468  ...   4.338453                 1.339078      1.234235       1.192543
# 30469  ...   1.204798                 1.340017      0.130667       1.644053
# 30470  ...   2.108265                 0.825811      0.378950       0.480531
#
#        church_synagogue_km  theater_km  museum_km       ecology  \
# 30466             0.612359    7.482165   4.836787          good
# 30467             0.310021    0.778428   1.450108          poor
# 30468             1.186621   13.459593   9.890758       no data
# 30469             0.476021    2.088193   4.119706  satisfactory
# 30470             0.867332    0.688707   0.127867          poor
#
#       mosque_count_1000 price_doc
# 30466                 0   7400000
# 30467                 0  25000000
# 30468                 0   6970959
# 30469                 0  13500000
# 30470                 0   5600000
#
# [5 rows x 61 columns]

# %%
path = '/Users/serdukovanton/Notebooks/IDE'
sber_data = pd.read_csv(path+'/sber_data.csv')
sber_data.head()
# Out:
#    id  full_sq  life_sq  floor           sub_area  preschool_quota  \
# 0   1       43     27.0    4.0           Bibirevo           5001.0
# 1   2       34     19.0    3.0  Nagatinskij Zaton           3119.0
# 2   3       43     29.0    2.0     Tekstil'shhiki           1463.0
# 3   4       89     50.0    9.0             Mitino           6839.0
# 4   5       77     77.0    4.0          Basmannoe           3240.0
#
#    preschool_education_centers_raion  school_quota  \
# 0                                  5       11065.0
# 1                                  5        6237.0
# 2                                  4        5580.0
# 3                                  9       17063.0
# 4                                  7        7770.0
#
#    school_education_centers_raion  school_education_centers_top_20_raion  ...  \
# 0                               5                                      0  ...
# 1                               8                                      0  ...
# 2                               7                                      0  ...
# 3                              10                                      0  ...
# 4                               9                                      0  ...
#
#    office_km  additional_education_km  preschool_km  big_church_km  \
# 0   0.637189                 0.947962      0.177975       0.625783
# 1   0.688796                 1.072315      0.273345       0.967821
# 2   1.543049                 0.391957      0.158072       3.178751
# 3   0.934273                 0.892674      0.236455       1.031777
# 4   0.077901                 0.810801      0.376838       0.378756
#
#    church_synagogue_km  theater_km  museum_km    ecology mosque_count_1000  \
# 0             0.628187   14.053047   7.389498       good                 0
# 1             0.471447    6.829889   0.709260  excellent                 0
# 2             0.755946    4.273200   3.156423       poor                 0
# 3             1.561505   16.990677  16.041521       good                 0
# 4             0.121681    1.112486   1.800125  excellent                 0
#
#   price_doc
# 0   5850000
# 1   6000000
# 2   5700000
# 3  13100000
# 4  16331452
#
# [5 rows x 61 columns]

# %%
sber_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30471 entries, 0 to 30470
# Data columns (total 61 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     30471 non-null  int64
#  1   full_sq                                30471 non-null  int64
#  2   life_sq                                24088 non-null  float64
#  3   floor                                  30304 non-null  float64
#  4   sub_area                               30471 non-null  object
#  5   preschool_quota                        23783 non-null  float64
#  6   preschool_education_centers_raion      30471 non-null  int64
#  7   school_quota                           23786 non-null  float64
#  8   school_education_centers_raion         30471 non-null  int64
#  9   school_education_centers_top_20_raion  30471 non-null  int64
#  10  hospital_beds_raion                    16030 non-null  float64
#  11  healthcare_centers_raion               30471 non-null  int64
#  12  university_top_20_raion                30471 non-null  int64
#  13  sport_objects_raion                    30471 non-null  int64
#  14  additional_education_raion             30471 non-null  int64
#  15  culture_objects_top_25_raion           30471 non-null  int64
#  16  shopping_centers_raion                 30471 non-null  int64
#  17  office_raion                           30471 non-null  int64
#  18  oil_chemistry_raion                    30471 non-null  object
#  19  railroad_terminal_raion                30471 non-null  object
#  20  nuclear_reactor_raion                  30471 non-null  object
#  21  metro_min_avto                         30471 non-null  float64
#  22  metro_km_avto                          30471 non-null  float64
#  23  metro_min_walk                         30446 non-null  float64
#  24  metro_km_walk                          30446 non-null  float64
#  25  kindergarten_km                        30471 non-null  float64
#  26  school_km                              30471 non-null  float64
#  27  park_km                                30471 non-null  float64
#  28  green_zone_km                          30471 non-null  float64
#  29  industrial_km                          30471 non-null  float64
#  30  railroad_station_walk_km               30446 non-null  float64
#  31  railroad_station_walk_min              30446 non-null  float64
#  32  public_transport_station_km            30471 non-null  float64
#  33  public_transport_station_min_walk      30471 non-null  float64
#  34  mkad_km                                30471 non-null  float64
#  35  ttk_km                                 30471 non-null  float64
#  36  sadovoe_km                             30471 non-null  float64
#  37  bulvar_ring_km                         30471 non-null  float64
#  38  kremlin_km                             30471 non-null  float64
#  39  big_road1_1line                        30471 non-null  object
#  40  big_market_km                          30471 non-null  float64
#  41  market_shop_km                         30471 non-null  float64
#  42  fitness_km                             30471 non-null  float64
#  43  swim_pool_km                           30471 non-null  float64
#  44  ice_rink_km                            30471 non-null  float64
#  45  stadium_km                             30471 non-null  float64
#  46  basketball_km                          30471 non-null  float64
#  47  hospice_morgue_km                      30471 non-null  float64
#  48  university_km                          30471 non-null  float64
#  49  workplaces_km                          30471 non-null  float64
#  50  shopping_centers_km                    30471 non-null  float64
#  51  office_km                              30471 non-null  float64
#  52  additional_education_km                30471 non-null  float64
#  53  preschool_km                           30471 non-null  float64
#  54  big_church_km                          30471 non-null  float64
#  55  church_synagogue_km                    30471 non-null  float64
#  56  theater_km                             30471 non-null  float64
#  57  museum_km                              30471 non-null  float64
#  58  ecology                                30471 non-null  object
#  59  mosque_count_1000                      30471 non-null  int64
#  60  price_doc                              30471 non-null  int64
# dtypes: float64(41), int64(14), object(6)
# memory usage: 14.2+ MB

# %%
sber_data['sub_area'].nunique()
# Out:
# 146

# %%
sber_data['price_doc'].max()
# Out:
# 111111112

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(20, 10))
plt.subplots_adjust(hspace=.0)

histplot1 = sns.histplot(data=sber_data, x='price_doc', bins=30)
histplot1.set_title('Распределение стоимости недвижимости в Москве и Подмосковье', fontsize=16)
histplot1.set_xlabel('Цена объекта')
histplot1.set_ylabel('Число объектов')
# Out:
# Text(0, 0.5, 'Число объектов')

# %%
fig = plt.figure(figsize=(10, 7))
barplot = sns.boxplot(
    data=sber_data,
    x='price_doc',
    y='ecology',
    orient='h',
    width=0.9
)
barplot.set_title('Зависимость цены недвижимости от экологического состояния райна');

# %%
fig = plt.figure(figsize=(8, 4))
axes = fig.add_axes([0, 0, 1, 1])
axes.scatter(
    x=sber_data['kremlin_km'], 
    y=sber_data['price_doc'], 
    s=1,
    marker='^',
    c = 'blue'
)

# %%
display(sber_data.isnull().tail())
# Out:
#           id  full_sq  life_sq  floor  sub_area  preschool_quota  \
# 30466  False    False    False  False     False            False
# 30467  False    False    False  False     False            False
# 30468  False    False     True  False     False             True
# 30469  False    False    False  False     False            False
# 30470  False    False    False  False     False            False
#
#        preschool_education_centers_raion  school_quota  \
# 30466                              False         False
# 30467                              False         False
# 30468                              False          True
# 30469                              False         False
# 30470                              False         False
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 30466                           False                                  False
# 30467                           False                                  False
# 30468                           False                                  False
# 30469                           False                                  False
# 30470                           False                                  False
#
#        ...  office_km  additional_education_km  preschool_km  big_church_km  \
# 30466  ...      False                    False         False          False
# 30467  ...      False                    False         False          False
# 30468  ...      False                    False         False          False
# 30469  ...      False                    False         False          False
# 30470  ...      False                    False         False          False
#
#        church_synagogue_km  theater_km  museum_km  ecology  mosque_count_1000  \
# 30466                False       False      False    False              False
# 30467                False       False      False    False              False
# 30468                False       False      False    False              False
# 30469                False       False      False    False              False
# 30470                False       False      False    False              False
#
#        price_doc
# 30466      False
# 30467      False
# 30468      False
# 30469      False
# 30470      False
#
# [5 rows x 61 columns]

# %%
cols_null_percent = sber_data.isnull().mean() * 100
cols_with_null = cols_null_percent[cols_null_percent>0].sort_values(ascending=False)
display(cols_with_null)
# Out:
# hospital_beds_raion          47.392603
# preschool_quota              21.948738
# school_quota                 21.938893
# life_sq                      20.947786
# floor                         0.548062
# railroad_station_walk_min     0.082045
# railroad_station_walk_km      0.082045
# metro_km_walk                 0.082045
# metro_min_walk                0.082045
# dtype: float64

# %%
cols_with_null.plot(
    kind='bar',
    figsize=(10, 4),
    title='Распределение пропусков в данных'
);

# %%
colors = ['blue', 'yellow'] 
fig = plt.figure(figsize=(10, 4))
cols = cols_with_null.index
display(cols)
ax = sns.heatmap(
    sber_data[cols].isnull(),
    cmap=sns.color_palette(colors),
)
# Out:
# Index(['hospital_beds_raion', 'preschool_quota', 'school_quota', 'life_sq',
#        'floor', 'railroad_station_walk_min', 'railroad_station_walk_km',
#        'metro_km_walk', 'metro_min_walk'],
#       dtype='object')

# %%
#создаем копию исходной таблицы
drop_data = sber_data.copy()
#задаем минимальный порог: вычисляем 70% от числа строк
thresh = drop_data.shape[0]*0.7
#удаляем столбцы, в которых более 30% (100-70) пропусков
drop_data = drop_data.dropna(how='any', thresh=thresh, axis=1)
#удаляем записи, в которых есть хотя бы 1 пропуск
drop_data = drop_data.dropna(how='any', axis=0)
#отоборажаем результирующую долю пропусков
drop_data.isnull().mean()
print(drop_data.shape)
# Out:
# (20888, 60)

# %%
cols = cols_with_null.index
sber_data[cols].hist(figsize=(20, 8), bins=5);

# %%
#создаем копию исходной таблицы
fill_data = sber_data.copy()
#создаем словарь имя столбца: число(признак) на который надо заменить пропуски
values = {
    'life_sq': fill_data['full_sq'],
    'metro_min_walk': fill_data['metro_min_walk'].median(),
    'metro_km_walk': fill_data['metro_km_walk'].median(),
    'railroad_station_walk_km': fill_data['railroad_station_walk_km'].median(),
    'railroad_station_walk_min': fill_data['railroad_station_walk_min'].median(),
    'hospital_beds_raion': fill_data['hospital_beds_raion'].mode()[0],
    'preschool_quota': fill_data['preschool_quota'].mode()[0],
    'school_quota': fill_data['school_quota'].mode()[0],
    'floor': fill_data['floor'].mode()[0]
}
#заполняем пропуски в соответствии с заявленным словарем
fill_data = fill_data.fillna(values)
#выводим результирующую долю пропусков
fill_data.isnull().mean()
# Out:
# id                   0.0
# full_sq              0.0
# life_sq              0.0
# floor                0.0
# sub_area             0.0
#                     ...
# theater_km           0.0
# museum_km            0.0
# ecology              0.0
# mosque_count_1000    0.0
# price_doc            0.0
# Length: 61, dtype: float64

# %%
#создаем копию исходной таблицы
fill_data = sber_data.copy()
#создаем словарь имя столбца: число(признак) на который надо заменить пропуски
values = {
    'life_sq': fill_data['full_sq'],
    'metro_min_walk': fill_data['metro_min_walk'].median(),
    'metro_km_walk': fill_data['metro_km_walk'].median(),
    'railroad_station_walk_km': fill_data['railroad_station_walk_km'].median(),
    'railroad_station_walk_min': fill_data['railroad_station_walk_min'].median(),
    'hospital_beds_raion': fill_data['hospital_beds_raion'].mode()[0],
    'preschool_quota': fill_data['preschool_quota'].mode()[0],
    'school_quota': fill_data['school_quota'].mode()[0],
    'floor': fill_data['floor'].mode()[0]
}
#заполняем пропуски в соответствии с заявленным словарем
fill_data = fill_data.fillna(values)
#выводим результирующую долю пропусков
fill_data.isnull().mean()
# Out:
# id                   0.0
# full_sq              0.0
# life_sq              0.0
# floor                0.0
# sub_area             0.0
#                     ...
# theater_km           0.0
# museum_km            0.0
# ecology              0.0
# mosque_count_1000    0.0
# price_doc            0.0
# Length: 61, dtype: float64

# %%
cols = cols_with_null.index
fill_data[cols].hist(figsize=(20, 8), bins=5);

# %%
#создаем копию исходной таблицы
indicator_data = sber_data.copy()
#в цикле пробегаемся по названиям столбцов с пропусками
for col in cols_with_null.index:
    #создаем новый признак-индикатор как col_was_null
    indicator_data[col + '_was_null'] = indicator_data[col].isnull()
#создаем словарь имя столбца: число(признак) на который надо заменить пропуски   
values = {
    'life_sq': indicator_data['full_sq'],
    'metro_min_walk': indicator_data['metro_min_walk'].median(),
    'metro_km_walk': indicator_data['metro_km_walk'].median(),
    'railroad_station_walk_km': indicator_data['railroad_station_walk_km'].median(),
    'railroad_station_walk_min': indicator_data['railroad_station_walk_min'].median(),
    'hospital_beds_raion': indicator_data['hospital_beds_raion'].mode()[0],
    'preschool_quota': indicator_data['preschool_quota'].mode()[0],
    'school_quota': indicator_data['school_quota'].mode()[0],
    'floor': indicator_data['floor'].mode()[0]
}
#заполняем пропуски в соответствии с заявленным словарем
indicator_data = indicator_data.fillna(values)
#выводим результирующую долю пропусков
indicator_data.isnull().mean()
# Out:
# id                                    0.0
# full_sq                               0.0
# life_sq                               0.0
# floor                                 0.0
# sub_area                              0.0
#                                      ...
# floor_was_null                        0.0
# railroad_station_walk_min_was_null    0.0
# railroad_station_walk_km_was_null     0.0
# metro_km_walk_was_null                0.0
# metro_min_walk_was_null               0.0
# Length: 70, dtype: float64

# %%
#создаём копию исходной таблицы
combine_data = sber_data.copy()

#отбрасываем столбцы с числом пропусков более 30% (100-70)
n = combine_data.shape[0] #число строк в таблице
thresh = n*0.7
combine_data = combine_data.dropna(how='any', thresh=thresh, axis=1)

#отбрасываем строки с числом пропусков более 2 в строке
m = combine_data.shape[1] #число признаков после удаления столбцов
combine_data = combine_data.dropna(how='any', thresh=m-2, axis=0)

#создаём словарь 'имя_столбца': число (признак), на который надо заменить пропуски 
values = {
    'life_sq': combine_data['full_sq'],
    'metro_min_walk': combine_data['metro_min_walk'].median(),
    'metro_km_walk': combine_data['metro_km_walk'].median(),
    'railroad_station_walk_km': combine_data['railroad_station_walk_km'].median(),
    'railroad_station_walk_min': combine_data['railroad_station_walk_min'].median(),
    'preschool_quota': combine_data['preschool_quota'].mode()[0],
    'school_quota': combine_data['school_quota'].mode()[0],
    'floor': combine_data['floor'].mode()[0]
}
#заполняем оставшиеся записи константами в соответствии со словарем values
combine_data = combine_data.fillna(values)
#выводим результирующую долю пропусков
display(combine_data.isnull().mean())
print(combine_data.shape)
# Out:
# id                                       0.0
# full_sq                                  0.0
# life_sq                                  0.0
# floor                                    0.0
# sub_area                                 0.0
# preschool_quota                          0.0
# preschool_education_centers_raion        0.0
# school_quota                             0.0
# school_education_centers_raion           0.0
# school_education_centers_top_20_raion    0.0
# healthcare_centers_raion                 0.0
# university_top_20_raion                  0.0
# sport_objects_raion                      0.0
# additional_education_raion               0.0
# culture_objects_top_25_raion             0.0
# shopping_centers_raion                   0.0
# office_raion                             0.0
# oil_chemistry_raion                      0.0
# railroad_terminal_raion                  0.0
# nuclear_reactor_raion                    0.0
# metro_min_avto                           0.0
# metro_km_avto                            0.0
# metro_min_walk                           0.0
# metro_km_walk                            0.0
# kindergarten_km                          0.0
# school_km                                0.0
# park_km                                  0.0
# green_zone_km                            0.0
# industrial_km                            0.0
# railroad_station_walk_km                 0.0
# railroad_station_walk_min                0.0
# public_transport_station_km              0.0
# public_transport_station_min_walk        0.0
# mkad_km                                  0.0
# ttk_km                                   0.0
# sadovoe_km                               0.0
# bulvar_ring_km                           0.0
# kremlin_km                               0.0
# big_road1_1line                          0.0
# big_market_km                            0.0
# market_shop_km                           0.0
# fitness_km                               0.0
# swim_pool_km                             0.0
# ice_rink_km                              0.0
# stadium_km                               0.0
# basketball_km                            0.0
# hospice_morgue_km                        0.0
# university_km                            0.0
# workplaces_km                            0.0
# shopping_centers_km                      0.0
# office_km                                0.0
# additional_education_km                  0.0
# preschool_km                             0.0
# big_church_km                            0.0
# church_synagogue_km                      0.0
# theater_km                               0.0
# museum_km                                0.0
# ecology                                  0.0
# mosque_count_1000                        0.0
# price_doc                                0.0
# dtype: float64
# (26800, 60)

# %%
sber_data['life_sq'].describe()
# Out:
# count    24088.000000
# mean        34.403271
# std         52.285733
# min          0.000000
# 25%         20.000000
# 50%         30.000000
# 75%         43.000000
# max       7478.000000
# Name: life_sq, dtype: float64

# %%
print(sber_data[sber_data['life_sq'] == 0].shape[0])
# Out:
# 45

# %%
display(sber_data[sber_data['life_sq'] > 7000])
# Out:
#           id  full_sq  life_sq  floor                 sub_area  \
# 13546  13549       79   7478.0    8.0  Poselenie Voskresenskoe
#
#        preschool_quota  preschool_education_centers_raion  school_quota  \
# 13546              NaN                                  0           NaN
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 13546                               0                                      0
#
#        ...  office_km  additional_education_km  preschool_km  big_church_km  \
# 13546  ...   5.072389                 1.210613      0.826052       1.582378
#
#        church_synagogue_km  theater_km  museum_km  ecology mosque_count_1000  \
# 13546             0.756119   21.472421  14.917332  no data                 0
#
#       price_doc
# 13546   7705000
#
# [1 rows x 61 columns]

# %%
outliers = sber_data[sber_data['life_sq'] > sber_data['full_sq']]
print(outliers.shape[0])
# Out:
# 37

# %%
cleaned = sber_data.drop(outliers.index, axis=0)
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Результирующее число записей: 30434

# %%
display(sber_data['floor'].describe())
# Out:
# count    30304.000000
# mean         7.670803
# std          5.319989
# min          0.000000
# 25%          3.000000
# 50%          6.500000
# 75%         11.000000
# max         77.000000
# Name: floor, dtype: float64

# %%
display(sber_data[sber_data['floor']> 50])
# Out:
#           id  full_sq  life_sq  floor       sub_area  preschool_quota  \
# 23584  23587       57     33.0   77.0  Lomonosovskoe           3091.0
#
#        preschool_education_centers_raion  school_quota  \
# 23584                                  5        8359.0
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 23584                               7                                      1
#
#        ...  office_km  additional_education_km  preschool_km  big_church_km  \
# 23584  ...   0.310557                 0.731683      0.489763        0.86354
#
#        church_synagogue_km  theater_km  museum_km       ecology  \
# 23584             0.863266    2.920671   2.757058  satisfactory
#
#       mosque_count_1000 price_doc
# 23584                 0  13700000
#
# [1 rows x 61 columns]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
histplot = sns.histplot(data=sber_data, x='full_sq', ax=axes[0]);
histplot.set_title('Full Square Distribution');
boxplot = sns.boxplot(data=sber_data, x='full_sq', ax=axes[1]);
boxplot.set_title('Full Square Boxplot');

# %%
def outliers_iqr(data, feature):
    x = data[feature]
    quartile_1, quartile_3 = x.quantile(0.25), x.quantile(0.75),
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 1.5)
    upper_bound = quartile_3 + (iqr * 1.5)
    outliers = data[(x<lower_bound) | (x > upper_bound)]
    cleaned = data[(x>lower_bound) & (x < upper_bound)]
    return outliers, cleaned

outliers, cleaned = outliers_iqr(sber_data, 'full_sq')
print(f'Число выбросов по методу Тьюки: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу Тьюки: 963
# Результирующее число записей: 29508

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
histplot = sns.histplot(data=cleaned, x='full_sq', ax=axes[0]);
histplot.set_title('Cleaned Full Square Distribution');
boxplot = sns.boxplot(data=cleaned, x='full_sq', ax=axes[1]);
boxplot.set_title('Cleaned Full Square Boxplot');

# %%
def outliers_iqr_mod(data, feature, left=1.5, right=1.5):
    x = data[feature]
    quartile_1, quartile_3 = x.quantile(0.25), x.quantile(0.75),
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * left)
    upper_bound = quartile_3 + (iqr * right)
    outliers = data[(x<lower_bound) | (x > upper_bound)]
    cleaned = data[(x>lower_bound) & (x < upper_bound)]
    return outliers, cleaned

outliers, cleaned = outliers_iqr_mod(sber_data, 'full_sq', 1, 6)
print(f'Число выбросов по методу Тьюки: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу Тьюки: 59
# Результирующее число записей: 30403

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
histplot = sns.histplot(data=cleaned, x='full_sq', ax=axes[0]);
histplot.set_title('Cleaned Full Square Distribution');
boxplot = sns.boxplot(data=cleaned, x='full_sq', ax=axes[1]);
boxplot.set_title('Cleaned Full Square Boxplot');

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 4))
#гистограмма исходного признака
histplot = sns.histplot(sber_data['mkad_km'], bins=30, ax=axes[0])
histplot.set_title('MKAD Km Distribution');
#гистограмма в логарифмическом масштабе
log_mkad_km= np.log(sber_data['mkad_km'] + 1)
histplot = sns.histplot(log_mkad_km , bins=30, ax=axes[1])
histplot.set_title('Log MKAD Km Distribution');

# %%
def outliers_z_score(data, feature, log_scale=False):
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - 3 * sigma
    upper_bound = mu + 3 * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x > lower_bound) & (x < upper_bound)]
    return outliers, cleaned

outliers, cleaned = outliers_z_score(sber_data, 'mkad_km', True)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу z-отклонения: 33
# Результирующее число записей: 30438

# %%
print(outliers['sub_area'].unique())
# Out:
# ['Poselenie Rogovskoe' 'Poselenie Kievskij']

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
log_mkad_km = np.log(sber_data['mkad_km'] + 1)
histplot = sns.histplot(log_mkad_km, bins=30, ax=ax)
histplot.axvline(log_mkad_km.mean(), color='k', lw=2)
histplot.axvline(log_mkad_km.mean()+ 3 * log_mkad_km.std(), color='k', ls='--', lw=1)
histplot.axvline(log_mkad_km.mean()- 3 * log_mkad_km.std(), color='k', ls='--', lw=1)
histplot.set_title('Log MKAD Km Distribution');

# %%
def outliers_z_score_mod(data, feature, log_scale=True, left = 3, right=3):
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x > lower_bound) & (x < upper_bound)]
    return outliers, cleaned

outliers, cleaned = outliers_z_score_mod(sber_data, 'mkad_km', log_scale = True, right=3.5)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу z-отклонения: 0
# Результирующее число записей: 30471

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
log_price = np.log(sber_data['price_doc'])
histplot = sns.histplot(log_price, bins=20, ax=ax)
histplot.set_title('Log Price Distribution');
histplot.axvline(log_price.mean(), color='k', lw=2)
histplot.axvline(log_price.mean()+ 3 * log_price.std(), color='k', ls='--', lw=2)
histplot.axvline(log_price.mean()- 3 * log_price.std(), color='k', ls='--', lw=2);

# %%
outliers, cleaned = outliers_z_score_mod(sber_data, 'price_doc', left=3.7, right=3.7)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу z-отклонения: 52
# Результирующее число записей: 30419

# %%
def outliers_iqr_mod(data, feature, log_scale=True, left=3, right=3):
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    quartile_1, quartile_3 = x.quantile(0.25), x.quantile(0.75),
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * left)
    upper_bound = quartile_3 + (iqr * right)
    outliers = data[(x<lower_bound) | (x > upper_bound)]
    cleaned = data[(x>lower_bound) & (x < upper_bound)]
    return outliers, cleaned

outliers, cleaned = outliers_iqr_mod(sber_data, 'price_doc')
print(f'Число выбросов по методу Тьюки: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу Тьюки: 92
# Результирующее число записей: 30379

# %%
sber_data['id'].nunique() == sber_data.shape[0]
# Out:
# True

# %%
dupl_columns = list(sber_data.columns)
dupl_columns.remove('id')

mask = sber_data.duplicated(subset=dupl_columns)
sber_duplicates = sber_data[mask]
print(f'Число найденных дубликатов: {sber_duplicates.shape[0]}')
# Out:
# Число найденных дубликатов: 562

# %%
sber_dedupped = sber_data.drop_duplicates(subset=dupl_columns)
print(f'Результирующее число записей: {sber_dedupped.shape[0]}')
# Out:
# Результирующее число записей: 29909

# %%
#список неинформативных признаков
low_information_cols = [] 

#цикл по всем столбцам
for col in sber_data.columns:
    #наибольшая относительная частота в признаке
    top_freq = sber_data[col].value_counts(normalize=True).max()
    #доля уникальных значений от размера признака
    nunique_ratio = sber_data[col].nunique() / sber_data[col].count()
    # сравниваем наибольшую частоту с порогом
    if top_freq > 0.95:
        low_information_cols.append(col)
        print(f'{col}: {round(top_freq*100, 2)}% одинаковых значений')
    # сравниваем долю уникальных значений с порогом
    if nunique_ratio > 0.95:
        low_information_cols.append(col)
        print(f'{col}: {round(nunique_ratio*100, 2)}% уникальных значений')
# Out:
# id: 100.0% уникальных значений
# oil_chemistry_raion: 99.03% одинаковых значений
# railroad_terminal_raion: 96.27% одинаковых значений
# nuclear_reactor_raion: 97.17% одинаковых значений
# big_road1_1line: 97.44% одинаковых значений
# mosque_count_1000: 98.08% одинаковых значений

# %%
information_sber_data = sber_data.drop(low_information_cols, axis=1)
print(f'Результирующее число признаков: {information_sber_data.shape[1]}')
# Out:
# Результирующее число признаков: 55

# %%
path = '/Users/serdukovanton/Notebooks/IDE'
diabetes = pd.read_csv(path + '/diabetes_data.csv')
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6       98             58             33      190  34.0
# 1            2      112             75             32        0  35.7
# 2            2      108             64              0        0  30.8
# 3            8      107             80              0        0  24.6
# 4            7      136             90              0        0  29.9
#
#    DiabetesPedigreeFunction  Age  Outcome  Gender
# 0                     0.430   43        0  Female
# 1                     0.148   21        0  Female
# 2                     0.158   21        0  Female
# 3                     0.856   34        0  Female
# 4                     0.210   50        0  Female

# %%
duplicates = diabetes[diabetes.duplicated()]
print('Число дубликтов: {}'.format(duplicates.shape[0]))
diabetes = diabetes.drop_duplicates()
print('Результирующее число записей: {}'.format(diabetes.shape[0]))
# Out:
# Число дубликтов: 10
# Результирующее число записей: 768

# %%
#список неинформативных признаков
low_information_cols = [] 

#цикл по всем столбцам
for col in diabetes.columns:
    #наибольшая относительная частота в признаке
    top_freq = diabetes[col].value_counts(normalize=True).max()
    #доля уникальных значений от размера признака
    nunique_ratio = diabetes[col].nunique() / diabetes[col].count()
    # сравниваем наибольшую частоту с порогом
    if top_freq > 0.99:
        low_information_cols.append(col)
        print(f'{col}: {round(top_freq*100, 2)}% одинаковых значений')
    # сравниваем долю уникальных значений с порогом
    if nunique_ratio > 0.99:
        low_information_cols.append(col)
        print(f'{col}: {round(nunique_ratio*100, 2)}% уникальных значений')
# Out:
# Gender: 100.0% одинаковых значений

# %%
def nan_function(x):
    return np.nan if x == 0 else x
diabetes["Glucose"] = diabetes["Glucose"].apply(nan_function)
diabetes["BloodPressure"] = diabetes["BloodPressure"].apply(nan_function)
diabetes["SkinThickness"] = diabetes["SkinThickness"].apply(nan_function)
diabetes["Insulin"] = diabetes["Insulin"].apply(nan_function)
diabetes["BMI"] = diabetes["BMI"].apply(nan_function)
diabetes.isnull().mean().round(2).sort_values(ascending=False)
# Out:
# Insulin                     0.49
# SkinThickness               0.30
# BloodPressure               0.05
# BMI                         0.01
# Glucose                     0.01
# Gender                      0.00
# Outcome                     0.00
# Age                         0.00
# DiabetesPedigreeFunction    0.00
# Pregnancies                 0.00
# dtype: float64

# %%
thresh = diabetes.shape[0]*0.7
diabetes_drop = diabetes.dropna(how='any', axis=1, thresh = thresh)
diabetes_drop = diabetes_drop.drop(['Gender'], axis=1)
print('Результирующее число записей: {}'.format(diabetes_drop.shape[1]))
# Out:
# Результирующее число записей: 8

# %%
m = diabetes.shape[1]
diabetes = diabetes.dropna(thresh=m-2, axis=0)
print(diabetes.shape[0])
# Out:
# 10
# 733

# %%
null_data = diabetes.isnull().sum()
display(null_data.index)
cols = null_data[null_data>0].index
for col in cols:
    diabetes[col] = diabetes[col].fillna(diabetes[col].median())
print(round(diabetes['SkinThickness'].mean(),2))
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome', 'Gender'],
#       dtype='object')
# 29.11

# %%
def outliers_iqr_mod(data, feature, left=1.5, right=1.5, log_scale=False):
    if log_scale:
        x = np.log(data[feature])
    else:
        x= data[feature]
    quartile_1, quartile_3 = x.quantile(0.25), x.quantile(0.75),
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * left)
    upper_bound = quartile_3 + (iqr * right)
    outliers = data[(x<lower_bound) | (x > upper_bound)]
    cleaned = data[(x>lower_bound) & (x < upper_bound)]
    return outliers, cleaned
outliers, _ = outliers_iqr_mod(diabetes, 'SkinThickness')
print(outliers.shape[0])
# Out:
# 32

# %%
def outliers_z_score_mod(data, feature, left=3, right=3, log_scale=False):
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x > lower_bound) & (x < upper_bound)]
    return outliers, cleaned
outliers, _ = outliers_z_score_mod(diabetes, 'SkinThickness')
print(outliers.shape[0])
# Out:
# 3

# %%
def outliers_iqr_mod(data, feature, left=1.5, right=1.5, log_scale=False):
    if log_scale:
        x = np.log(data[feature])
    else:
        x= data[feature]
    quartile_1, quartile_3 = x.quantile(0.25), x.quantile(0.75),
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * left)
    upper_bound = quartile_3 + (iqr * right)
    outliers = data[(x<lower_bound) | (x > upper_bound)]
    cleaned = data[(x>lower_bound) & (x < upper_bound)]
    return outliers, cleaned
outliers, _ = outliers_iqr_mod(diabetes, 'DiabetesPedigreeFunction')
outliers_log, _ = outliers_iqr_mod(diabetes, 'DiabetesPedigreeFunction', log_scale=True)
print(outliers.shape[0] - outliers_log.shape[0])
# Out:
# 29

# %%
class SalesReport():  
    def __init__(self):  
        self.deals = []  
          
    def add_deal(self, amount):   
        self.deals.append(amount)  
          
    def total_amount(self):  
        return sum(self.deals)  
      
    def print_report(self):  
        print("Total sales:", self.total_amount())  
   
report = SalesReport()  
print(report.deals)  
# => []  
report.total_amount()  
# => 0
# Out:
# []
# 0

# %%
class SalesReport():  
    # Будем принимать в __init__ ещё и имя менеджера  
    def __init__(self, manager_name):  
        self.deals = []  
        self.manager_name = manager_name  
          
    def add_deal(self, amount):   
        self.deals.append(amount)  
          
    def total_amount(self):  
        return sum(self.deals)  
      
    def print_report(self):  
        # И добавлять это имя в отчёт  
        print("Manager:", self.manager_name)  
        print("Total sales:", self.total_amount())  
          
   
report = SalesReport("Ivan Taranov")  
report.add_deal(10_000)  
report.add_deal(30_000)  
report.print_report()
# Out:
# Manager: Ivan Taranov
# Total sales: 40000

# %%
class DepartmentReport():

    def __init__(self,company):
        self.revenues=[]
        self.company=company
    
    def add_revenue(self, amount):
        if not hasattr(self,'revenues'):
            self.revenues=[]
        self.revenues.append(amount)
    
    def average_revenue(self):
        if len(self.revenues) >0:
            average=round(sum(self.revenues)/len(self.revenues))
            return 'Average department revenue for {}: {}'.format(self.company,average)
        else:
            return 'No deals are recorded yet'

report = DepartmentReport("Danon")
report.add_revenue(1_000_000)
report.add_revenue(400_000)

print(report.average_revenue())
# Out:
# Average department revenue for Danon: 700000

# %%
class SalesReport():  
    def __init__(self, employee_name):  
        self.deals = []  
        self.employee_name = employee_name  
      
    def add_deal(self, company, amount):   
        self.deals.append({'company': company, 'amount': amount})  
          
    def total_amount(self):  
        return sum([elem['amount'] for elem in self.deals])  
      
    def average_deal(self):  
        return self.total_amount()/len(self.deals)  
      
    def all_companies(self):  
        return list(set([deal['company'] for deal in self.deals]))  
      
    def print_report(self):  
        print("Employee: ", self.employee_name)  
        print("Total sales:", self.total_amount())  
        print("Average sales:", self.average_deal())  
        print("Companies:", self.all_companies())  
      
      
report = SalesReport("Ivan Semenov") 
report.add_deal("PepsiCo", 120_000)  
report.add_deal("SkyEng", 250_000)  
report.add_deal("PepsiCo", 20_000)  
report.print_report()
# Out:
# Employee:  Ivan Semenov
# Total sales: 390000
# Average sales: 130000.0
# Companies: ['SkyEng', 'PepsiCo']

# %%
class Client():  
    # Базовые данные  
    def __init__(self, email, order_num, registration_year):  
        self.email = email  
        self.order_num = order_num  
        self.registration_year = registration_year  
        self.discount = 0  
          
    # Оформление заказа  
    def make_order(self, price):  
        self.update_discount()  
        self.order_num += 1  
        # Здесь было бы оформление заказа, но мы просто выведем его цену  
        discounted_price = price * (1 - self.discount)   
        print(f"Order price for {self.email} is {discounted_price}")  
              
    # Назначение скидки  
    def update_discount(self):   
        if self.registration_year < 2018 and self.order_num >= 5:  
            self.discount = 0.1   
              
  
# Применение  
          
# Сделаем подобие базы  
client_db = [   
    Client("max@gmail.com", 2, 2019),  
    Client("lova@yandex.ru", 10, 2015),  
    Client("german@sberbank.ru", 4, 2017)  
]  
  
  
# Сгенерируем заказы  
client_db[0].make_order(100)  
client_db[1].make_order(200)  
client_db[2].make_order(500)  
client_db[2].make_order(500)
# Out:
# Order price for max@gmail.com is 100
# Order price for lova@yandex.ru is 180.0
# Order price for german@sberbank.ru is 500
# Order price for german@sberbank.ru is 450.0

# %%
class User():
    def __init__(self, email, password, balance):
        self.email=email
        self.password=password
        self.balance=balance
        update_balance=0
     
    def login(self, email, password):
        if self.email==email and self.password==password:
            answer=True
        else:
            answer=False
        return answer
    
    def update_balance(self, amount):
        self.balance+=amount
        return self.balance

user = User("gosha@roskino.org", "qwerty", 20_000)
user.login("gosha@roskino.org", "qwerty123")
# => False
user.login("gosha@roskino.org", "qwerty")
# => True
user.update_balance(200)
user.update_balance(-500)
print(user.balance)
# => 19700
# Out:
# 19700

# %%
import statistics  
  
class DataFrame():  
    def __init__(self, column, fill_value=0):  
        # Инициализируем атрибуты  
        self.column = column  
        self.fill_value = fill_value  
        # Заполним пропуски  
        self.fill_missed()  
        # Конвертируем все элементы в числа  
        self.to_float()  
          
    def fill_missed(self):  
        for i, value in enumerate(self.column):
            if value is None or value == '':  
                self.column[i] = self.fill_value  
                  
    def to_float(self):  
        self.column = [float(value) for value in self.column]  
      
    def median(self):  
        return statistics.median(self.column)  
      
    def mean(self):  
        return statistics.mean(self.column)  
      
    def deviation(self):  
        return statistics.stdev(self.column)  
      
  
      
# Воспользуемся классом  
df = DataFrame(["1", 17, 4, None, 8])
  
print(df.column)  
# => [1.0, 17.0, 4.0, 0.0, 8.0]  
print(df.deviation())  
# => 6.89  
print(df.median())  
# => 4.0
# Out:
# <enumerate object at 0x7f904f22d500>
# <enumerate object at 0x7f904f22d500>
# <enumerate object at 0x7f904f22d500>
# <enumerate object at 0x7f904f22d500>
# <enumerate object at 0x7f904f22d500>
# [1.0, 17.0, 4.0, 0.0, 8.0]
# 6.892024376045111
# 4.0

# %%
class OwnLogger():
   def __init__(self):
       self.logs = {"info": None, "warning": None, "error": None, "all": None}
   def log(self, message, level):
       self.logs[level] = message
       self.logs['all'] = message
   def show_last(self, level='all'):
       return self.logs[level]

logger = OwnLogger()
logger.log("System started", "info")
logger.show_last("error")
# => None
# Некоторые интерпретаторы Python могут не выводить None, тогда в этой проверке у вас будет пустая строка
logger.log("Connection instable", "warning")
logger.log("Connection lost", "error")

logger.show_last()
# => Connection lost
logger.show_last("info")
# => System started
# Out:
# 'System started'

# %%
class Dog():    
    def bark(*args):
        return 'Bark!'
    
    def give_paw(*args):
        return 'Paw'

# %%
import os
# получить текущий путь
start_path = os.getcwd()
print(start_path) 

os.chdir("..") # подняться на один уровень выше
os.getcwd()

os.chdir(start_path)
os.getcwd()

print(os.listdir()) # ['SnapchatLoader', 'FBLoader', 'tmp.py', '.gitignore', 'venv', '.git']

if 'tmp.py' not in os.listdir():
    print("Файл отсутствует в данной директории")

print(start_path)
print(os.path.join(start_path))
# Out:
# /Users/serdukovanton/Notebooks
# ['IDE', 'Old DS', '.DS_Store', 'Projects', 'New DS', '.ipynb_checkpoints', 'data', 'Super game']
# Файл отсутствует в данной директории
# /Users/serdukovanton/Notebooks
# /Users/serdukovanton/Notebooks

# %%
def walk_desc(path=None):
    start_path = path if path is not None else os.getcwd()

    for root, dirs, files in os.walk(start_path):
        print("Текущая директория", root)
        print("---")

        if dirs:
            print("Список папок", dirs)
        else:
            print("Папок нет")
        print("---")

        if files:
            print("Список файлов", files)
        else:
            print("Файлов нет")
        print("---")

        if files and dirs:
            print("Все пути:")
        for f in files:
            print("Файл ", os.path.join(root, f))
        for d in dirs:
            print("Папка ", os.path.join(root, d))
        print("===")

walk_desc()

walk_desc()
# Out:
# Текущая директория /Users/serdukovanton/Notebooks
# ---
# Список папок ['IDE', 'Old DS', 'Projects', 'New DS', '.ipynb_checkpoints', 'data', 'Super game']
# ---
# Список файлов ['.DS_Store']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/.DS_Store
# Папка  /Users/serdukovanton/Notebooks/IDE
# Папка  /Users/serdukovanton/Notebooks/Old DS
# Папка  /Users/serdukovanton/Notebooks/Projects
# Папка  /Users/serdukovanton/Notebooks/New DS
# Папка  /Users/serdukovanton/Notebooks/.ipynb_checkpoints
# Папка  /Users/serdukovanton/Notebooks/data
# Папка  /Users/serdukovanton/Notebooks/Super game
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE
# ---
# Список папок ['.git', '.vscode', 'Super game']
# ---
# Список файлов ['Python-14', '.DS_Store', 'diabetes_data.csv', 'workspace.code-workspace', 'requirements.txt', 'README.md', 'NewFile.ipynb', 'sber_data.csv', 'Python-14.ipynb']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/IDE/Python-14
# Файл  /Users/serdukovanton/Notebooks/IDE/.DS_Store
# Файл  /Users/serdukovanton/Notebooks/IDE/diabetes_data.csv
# Файл  /Users/serdukovanton/Notebooks/IDE/workspace.code-workspace
# Файл  /Users/serdukovanton/Notebooks/IDE/requirements.txt
# Файл  /Users/serdukovanton/Notebooks/IDE/README.md
# Файл  /Users/serdukovanton/Notebooks/IDE/NewFile.ipynb
# Файл  /Users/serdukovanton/Notebooks/IDE/sber_data.csv
# Файл  /Users/serdukovanton/Notebooks/IDE/Python-14.ipynb
# Папка  /Users/serdukovanton/Notebooks/IDE/.git
# Папка  /Users/serdukovanton/Notebooks/IDE/.vscode
# Папка  /Users/serdukovanton/Notebooks/IDE/Super game
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git
# ---
# Список папок ['objects', 'info', 'logs', 'hooks', 'refs']
# ---
# Список файлов ['ORIG_HEAD', 'config', 'HEAD', 'description', 'index', 'packed-refs', 'COMMIT_EDITMSG', 'FETCH_HEAD']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/ORIG_HEAD
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/config
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/HEAD
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/description
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/index
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/packed-refs
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/COMMIT_EDITMSG
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/FETCH_HEAD
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/info
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/logs
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/hooks
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/refs
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects
# ---
# Список папок ['61', '0d', '3e', '3b', '6f', '6a', '69', '3c', '56', '93', '94', '34', 'a4', 'b5', 'bb', 'd8', 'f3', 'fe', 'ec', '20', '18', 'pack', '1f', '73', '28', '17', '4c', '26', '21', '4d', '86', '44', '43', '6e', '9a', '36', '5d', 'info', '65', '3a', '54', '98', '3f', '30', '5e', '37', '08', '01', '52', '0f', '0a', 'a7', 'b1', 'dc', 'b6', 'd5', 'db', 'a6', 'c3', 'ea', 'cd', 'e6', 'f7', 'e8', 'c2', '2c', '2d', '24', '8d', '8c', '85', '1c', '40', '2e', '7a', '14']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/61
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/0d
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/3e
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/3b
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/6f
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/6a
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/69
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/3c
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/56
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/93
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/94
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/34
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/a4
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/b5
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/bb
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/d8
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/f3
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/fe
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/ec
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/20
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/18
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/pack
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/1f
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/73
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/28
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/17
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/4c
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/26
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/21
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/4d
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/86
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/44
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/43
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/6e
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/9a
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/36
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/5d
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/info
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/65
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/3a
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/54
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/98
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/3f
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/30
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/5e
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/37
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/08
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/01
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/52
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/0f
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/0a
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/a7
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/b1
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/dc
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/b6
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/d5
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/db
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/a6
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/c3
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/ea
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/cd
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/e6
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/f7
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/e8
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/c2
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/2c
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/2d
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/24
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/8d
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/8c
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/85
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/1c
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/40
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/2e
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/7a
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/objects/14
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/61
# ---
# Папок нет
# ---
# Список файлов ['eb3786048b42367530a56844e1f3f1683a91bd']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/61/eb3786048b42367530a56844e1f3f1683a91bd
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/0d
# ---
# Папок нет
# ---
# Список файлов ['636d5b6024268dc97c8aa3343a720a0d4626d3']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/0d/636d5b6024268dc97c8aa3343a720a0d4626d3
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/3e
# ---
# Папок нет
# ---
# Список файлов ['3d8e110296d91bb74383e5d9fd3cf261871ae6']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/3e/3d8e110296d91bb74383e5d9fd3cf261871ae6
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/3b
# ---
# Папок нет
# ---
# Список файлов ['9a300ec07d50675e0c83b1975ef7846a06ca64']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/3b/9a300ec07d50675e0c83b1975ef7846a06ca64
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/6f
# ---
# Папок нет
# ---
# Список файлов ['d9cbde1e34dcc755c8df9eafb8dcc1eac6bafd']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/6f/d9cbde1e34dcc755c8df9eafb8dcc1eac6bafd
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/6a
# ---
# Папок нет
# ---
# Список файлов ['fd807f9ca79f3a5072fb191b1bc475793a140f']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/6a/fd807f9ca79f3a5072fb191b1bc475793a140f
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/69
# ---
# Папок нет
# ---
# Список файлов ['a5ac0d4e91bf9d5ad31e2514da3b73ea490b3a']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/69/a5ac0d4e91bf9d5ad31e2514da3b73ea490b3a
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/3c
# ---
# Папок нет
# ---
# Список файлов ['42a3e4fe78ebdbd85d20c476b9403c09b3476e']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/3c/42a3e4fe78ebdbd85d20c476b9403c09b3476e
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/56
# ---
# Папок нет
# ---
# Список файлов ['3d48fcf02bbe1e646e396d14198347cbc7d57b']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/56/3d48fcf02bbe1e646e396d14198347cbc7d57b
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/93
# ---
# Папок нет
# ---
# Список файлов ['327641023f401e6352709873595fbf6150d3ba']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/93/327641023f401e6352709873595fbf6150d3ba
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/94
# ---
# Папок нет
# ---
# Список файлов ['44c6cae81a937d2572ce60b15dbde7fa601c2b']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/94/44c6cae81a937d2572ce60b15dbde7fa601c2b
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/34
# ---
# Папок нет
# ---
# Список файлов ['b875e1bb5f3752508276791b22c02d67fffc22']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/34/b875e1bb5f3752508276791b22c02d67fffc22
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/a4
# ---
# Папок нет
# ---
# Список файлов ['807ac7b276df7b19091e98697c4196b6c56598']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/a4/807ac7b276df7b19091e98697c4196b6c56598
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/b5
# ---
# Папок нет
# ---
# Список файлов ['5aa74b358afa6f20242d6e26520c463a27cc95', '780893896b374fffe66877d796ed8b9e4950db']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/b5/5aa74b358afa6f20242d6e26520c463a27cc95
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/b5/780893896b374fffe66877d796ed8b9e4950db
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/bb
# ---
# Папок нет
# ---
# Список файлов ['528d006569e4df4a87a615090fd98063f7f14f']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/bb/528d006569e4df4a87a615090fd98063f7f14f
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/d8
# ---
# Папок нет
# ---
# Список файлов ['46924b00256eecfcbcf7b44d95efa3984dabd1']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/d8/46924b00256eecfcbcf7b44d95efa3984dabd1
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/f3
# ---
# Папок нет
# ---
# Список файлов ['47ab32d5ec754d94b14cc0752c62bad92f5056']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/f3/47ab32d5ec754d94b14cc0752c62bad92f5056
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/fe
# ---
# Папок нет
# ---
# Список файлов ['82f4cb6628eee5a5b528f8e8509277bbfeaff0']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/fe/82f4cb6628eee5a5b528f8e8509277bbfeaff0
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/ec
# ---
# Папок нет
# ---
# Список файлов ['f27f47f68a08540e4a1d47430f3295ba56871b', 'dd86d9881550ea5e8591cd60491d73a565a97b']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/ec/f27f47f68a08540e4a1d47430f3295ba56871b
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/ec/dd86d9881550ea5e8591cd60491d73a565a97b
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/20
# ---
# Папок нет
# ---
# Список файлов ['eecd50a60487f42ee7351846c97e6d9120af7a']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/20/eecd50a60487f42ee7351846c97e6d9120af7a
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/18
# ---
# Папок нет
# ---
# Список файлов ['f186a5e95c940030b2ce8f82304b6824014967']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/18/f186a5e95c940030b2ce8f82304b6824014967
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/pack
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/1f
# ---
# Папок нет
# ---
# Список файлов ['106837063262518b0b0ba58a7b1b54bba73189']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/1f/106837063262518b0b0ba58a7b1b54bba73189
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/73
# ---
# Папок нет
# ---
# Список файлов ['f29f99fddeabb232337087892fbc3cb1255410', '3156672f64212e8c1179de155528c0498c2276']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/73/f29f99fddeabb232337087892fbc3cb1255410
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/73/3156672f64212e8c1179de155528c0498c2276
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/28
# ---
# Папок нет
# ---
# Список файлов ['f1272ffcecf82d5105b84185d92ca70248c506']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/28/f1272ffcecf82d5105b84185d92ca70248c506
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/17
# ---
# Папок нет
# ---
# Список файлов ['7e3aaad74aa7c78c1824ec8d103133852d379a']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/17/7e3aaad74aa7c78c1824ec8d103133852d379a
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/4c
# ---
# Папок нет
# ---
# Список файлов ['62488fabae79e964d965d966f6658a3b3df784']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/4c/62488fabae79e964d965d966f6658a3b3df784
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/26
# ---
# Папок нет
# ---
# Список файлов ['15ae6a4c9e9861ddd5cf1d8541f062f7786255']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/26/15ae6a4c9e9861ddd5cf1d8541f062f7786255
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/21
# ---
# Папок нет
# ---
# Список файлов ['fbbd3e9326bad76f2aa5dfbc147570c1c4d655']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/21/fbbd3e9326bad76f2aa5dfbc147570c1c4d655
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/4d
# ---
# Папок нет
# ---
# Список файлов ['a1675b2ce2634f65a5733b3163a7f5bdb87b87', '68506689feb148ce6a74fd69108b85b31b7e86']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/4d/a1675b2ce2634f65a5733b3163a7f5bdb87b87
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/4d/68506689feb148ce6a74fd69108b85b31b7e86
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/86
# ---
# Папок нет
# ---
# Список файлов ['7774106ad7ed50c53da955f8471a13ae4c8fcd']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/86/7774106ad7ed50c53da955f8471a13ae4c8fcd
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/44
# ---
# Папок нет
# ---
# Список файлов ['4b4a3a46ba12d93f27de95a39ce1aa0a7f20d2']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/44/4b4a3a46ba12d93f27de95a39ce1aa0a7f20d2
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/43
# ---
# Папок нет
# ---
# Список файлов ['50a8034971f7387b7abbb14de9d765bdde1b08', '0bbf96f874b4a7bd017656435b934768228144']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/43/50a8034971f7387b7abbb14de9d765bdde1b08
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/43/0bbf96f874b4a7bd017656435b934768228144
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/6e
# ---
# Папок нет
# ---
# Список файлов ['649b29a0e65d8022c64ba4e959d6cf1b83b9fc']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/6e/649b29a0e65d8022c64ba4e959d6cf1b83b9fc
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/9a
# ---
# Папок нет
# ---
# Список файлов ['ad74f126bfd0163ee0cb5eb888cc69d629d20c']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/9a/ad74f126bfd0163ee0cb5eb888cc69d629d20c
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/36
# ---
# Папок нет
# ---
# Список файлов ['2f88ad612e1695a4b3d488459e64fb9214f0bf']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/36/2f88ad612e1695a4b3d488459e64fb9214f0bf
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/5d
# ---
# Папок нет
# ---
# Список файлов ['a28735331de52f4708400b001ac7633c413fe6']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/5d/a28735331de52f4708400b001ac7633c413fe6
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/info
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/65
# ---
# Папок нет
# ---
# Список файлов ['d096a4d609aa2f87083e4eacc955ca5d1af494']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/65/d096a4d609aa2f87083e4eacc955ca5d1af494
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/3a
# ---
# Папок нет
# ---
# Список файлов ['4ed39ce72483a3511a7eeb8a2a04ea45dd5c34']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/3a/4ed39ce72483a3511a7eeb8a2a04ea45dd5c34
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/54
# ---
# Папок нет
# ---
# Список файлов ['b4c6447f6253890d9bd67f508da49e0794070a']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/54/b4c6447f6253890d9bd67f508da49e0794070a
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/98
# ---
# Папок нет
# ---
# Список файлов ['277bbb397821f9c2e25d1370217ad71bac33a8']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/98/277bbb397821f9c2e25d1370217ad71bac33a8
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/3f
# ---
# Папок нет
# ---
# Список файлов ['12f39ddd3d99ff9550ea98897d203ed75cff20']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/3f/12f39ddd3d99ff9550ea98897d203ed75cff20
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/30
# ---
# Папок нет
# ---
# Список файлов ['c1931eac1021e295657d2b56d6b01a71d14cdb']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/30/c1931eac1021e295657d2b56d6b01a71d14cdb
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/5e
# ---
# Папок нет
# ---
# Список файлов ['79b5dd04f419df7221e68526df20b34ada5bed', '7f4a170141c079ad6ab0724f40001ce2a06d49']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/5e/79b5dd04f419df7221e68526df20b34ada5bed
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/5e/7f4a170141c079ad6ab0724f40001ce2a06d49
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/37
# ---
# Папок нет
# ---
# Список файлов ['d24c0fc2194c542ff8b888a386d12dabe2d467', 'a9c82c1603d31b81d86a34e4f02363f67b4f69']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/37/d24c0fc2194c542ff8b888a386d12dabe2d467
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/37/a9c82c1603d31b81d86a34e4f02363f67b4f69
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/08
# ---
# Папок нет
# ---
# Список файлов ['d15a2fb25649336c0aa26caede9084fc320a15']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/08/d15a2fb25649336c0aa26caede9084fc320a15
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/01
# ---
# Папок нет
# ---
# Список файлов ['6fb5c6be4f14f369e97f7317ef10ea581693d6']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/01/6fb5c6be4f14f369e97f7317ef10ea581693d6
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/52
# ---
# Папок нет
# ---
# Список файлов ['59fb51dbab9df63c56b227c81f4d6559912483']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/52/59fb51dbab9df63c56b227c81f4d6559912483
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/0f
# ---
# Папок нет
# ---
# Список файлов ['7b8d9023722c8a654a78366712fff92a963b29']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/0f/7b8d9023722c8a654a78366712fff92a963b29
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/0a
# ---
# Папок нет
# ---
# Список файлов ['cb07a78956f14afff7bc1512299d9478689e04', '792afcd1e704c245ceb6c51b91620632fe09e1', '3fe65a6421c138fad673a5f1768ba38b2f3362']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/0a/cb07a78956f14afff7bc1512299d9478689e04
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/0a/792afcd1e704c245ceb6c51b91620632fe09e1
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/0a/3fe65a6421c138fad673a5f1768ba38b2f3362
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/a7
# ---
# Папок нет
# ---
# Список файлов ['ffbb33a08659cc4255cc9351cda4f736d1d9ed']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/a7/ffbb33a08659cc4255cc9351cda4f736d1d9ed
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/b1
# ---
# Папок нет
# ---
# Список файлов ['abe37adf8a634f7165d207a140d8d46089f911']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/b1/abe37adf8a634f7165d207a140d8d46089f911
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/dc
# ---
# Папок нет
# ---
# Список файлов ['03d0ec06ac1ed75bd28a58e85d1ca1adc174d0']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/dc/03d0ec06ac1ed75bd28a58e85d1ca1adc174d0
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/b6
# ---
# Папок нет
# ---
# Список файлов ['5da4d9e886fbbbd99b08156e44d97629ced1d3']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/b6/5da4d9e886fbbbd99b08156e44d97629ced1d3
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/d5
# ---
# Папок нет
# ---
# Список файлов ['db4d228780033b5b40fd978a6ac9beebfa924d']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/d5/db4d228780033b5b40fd978a6ac9beebfa924d
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/db
# ---
# Папок нет
# ---
# Список файлов ['adbf10fad6931f0a421860362a526b37178556', '09b73b3a055b7a6f76cabe153d4d6cc7a423d9']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/db/adbf10fad6931f0a421860362a526b37178556
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/db/09b73b3a055b7a6f76cabe153d4d6cc7a423d9
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/a6
# ---
# Папок нет
# ---
# Список файлов ['395ea977bb60ff8b3646a4732a26228909c4eb']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/a6/395ea977bb60ff8b3646a4732a26228909c4eb
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/c3
# ---
# Папок нет
# ---
# Список файлов ['118a2f2a0a9184fbd3f923cf84711a01761bd0']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/c3/118a2f2a0a9184fbd3f923cf84711a01761bd0
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/ea
# ---
# Папок нет
# ---
# Список файлов ['9997c0375d0cc9397b3973158bb4441404fe1d', '78a2ea7698ba0daab65b3875dd93b7dd7d21ca']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/ea/9997c0375d0cc9397b3973158bb4441404fe1d
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/ea/78a2ea7698ba0daab65b3875dd93b7dd7d21ca
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/cd
# ---
# Папок нет
# ---
# Список файлов ['e0f0318caa0b14b2f25ccfa4f649b1453df6d1', '99bf044211a3e502fdb3a5b67750a3be51172c']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/cd/e0f0318caa0b14b2f25ccfa4f649b1453df6d1
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/cd/99bf044211a3e502fdb3a5b67750a3be51172c
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/e6
# ---
# Папок нет
# ---
# Список файлов ['6431c11d3035b542adf7b3c2ac3e0ba50de1dd']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/e6/6431c11d3035b542adf7b3c2ac3e0ba50de1dd
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/f7
# ---
# Папок нет
# ---
# Список файлов ['33744d0a1c34dd965d4bc82acbeac3e00e9cab']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/f7/33744d0a1c34dd965d4bc82acbeac3e00e9cab
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/e8
# ---
# Папок нет
# ---
# Список файлов ['7b21c47a36508056940e37b65120d534380bfb']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/e8/7b21c47a36508056940e37b65120d534380bfb
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/c2
# ---
# Папок нет
# ---
# Список файлов ['8db2651e4b4eb7f3c05b10f54ba4c13b92e735']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/c2/8db2651e4b4eb7f3c05b10f54ba4c13b92e735
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/2c
# ---
# Папок нет
# ---
# Список файлов ['df74754681da396d8ed53f6172a40b6c92cff6']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/2c/df74754681da396d8ed53f6172a40b6c92cff6
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/2d
# ---
# Папок нет
# ---
# Список файлов ['29ab3b5364756277b00788eaf7c1342e4a5b2a']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/2d/29ab3b5364756277b00788eaf7c1342e4a5b2a
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/24
# ---
# Папок нет
# ---
# Список файлов ['a2c224f52b9aad1fade1e4e61836700f85395f']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/24/a2c224f52b9aad1fade1e4e61836700f85395f
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/8d
# ---
# Папок нет
# ---
# Список файлов ['6b3b3e1991e1adc81447670570d781f53e218d']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/8d/6b3b3e1991e1adc81447670570d781f53e218d
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/8c
# ---
# Папок нет
# ---
# Список файлов ['1639273d75aca45e39d071a422c2d32e99ea16']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/8c/1639273d75aca45e39d071a422c2d32e99ea16
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/85
# ---
# Папок нет
# ---
# Список файлов ['388f7adb616d08a7a0b2a7a81ffe75ceb15978']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/85/388f7adb616d08a7a0b2a7a81ffe75ceb15978
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/1c
# ---
# Папок нет
# ---
# Список файлов ['04c7d5b311624c2b50b88efa125f98ab3ebc98', 'bc58e2c73d7436bbf0a9847b42b0c751f537ba']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/1c/04c7d5b311624c2b50b88efa125f98ab3ebc98
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/1c/bc58e2c73d7436bbf0a9847b42b0c751f537ba
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/40
# ---
# Папок нет
# ---
# Список файлов ['44c6b69c9a759bf981a1dad336b1dc621d7daa']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/40/44c6b69c9a759bf981a1dad336b1dc621d7daa
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/2e
# ---
# Папок нет
# ---
# Список файлов ['c5fd9a540df26e96184a723b5de4acfe78b0c6']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/2e/c5fd9a540df26e96184a723b5de4acfe78b0c6
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/7a
# ---
# Папок нет
# ---
# Список файлов ['70fdc8bfc3930d6291a437982925553063456a']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/7a/70fdc8bfc3930d6291a437982925553063456a
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/objects/14
# ---
# Папок нет
# ---
# Список файлов ['406a5d4cdcf2446dd4c739569b1a3f12a74ef5']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/objects/14/406a5d4cdcf2446dd4c739569b1a3f12a74ef5
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/info
# ---
# Папок нет
# ---
# Список файлов ['exclude']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/info/exclude
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/logs
# ---
# Список папок ['refs']
# ---
# Список файлов ['HEAD']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/logs/HEAD
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/logs/refs
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/logs/refs
# ---
# Список папок ['heads', 'remotes']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/logs/refs/heads
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/logs/refs/remotes
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/logs/refs/heads
# ---
# Папок нет
# ---
# Список файлов ['master', 'main']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/logs/refs/heads/master
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/logs/refs/heads/main
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/logs/refs/remotes
# ---
# Список папок ['MyRepository']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/logs/refs/remotes/MyRepository
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/logs/refs/remotes/MyRepository
# ---
# Папок нет
# ---
# Список файлов ['master', 'main']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/logs/refs/remotes/MyRepository/master
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/logs/refs/remotes/MyRepository/main
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/hooks
# ---
# Папок нет
# ---
# Список файлов ['commit-msg.sample', 'pre-rebase.sample', 'pre-commit.sample', 'applypatch-msg.sample', 'fsmonitor-watchman.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'post-update.sample', 'pre-merge-commit.sample', 'pre-applypatch.sample', 'pre-push.sample', 'update.sample', 'push-to-checkout.sample']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/hooks/commit-msg.sample
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/hooks/pre-rebase.sample
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/hooks/pre-commit.sample
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/hooks/applypatch-msg.sample
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/hooks/fsmonitor-watchman.sample
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/hooks/pre-receive.sample
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/hooks/prepare-commit-msg.sample
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/hooks/post-update.sample
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/hooks/pre-merge-commit.sample
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/hooks/pre-applypatch.sample
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/hooks/pre-push.sample
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/hooks/update.sample
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/hooks/push-to-checkout.sample
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/refs
# ---
# Список папок ['heads', 'tags', 'remotes']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/refs/heads
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/refs/tags
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/refs/remotes
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/refs/heads
# ---
# Папок нет
# ---
# Список файлов ['master', 'main']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/refs/heads/master
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/refs/heads/main
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/refs/tags
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/refs/remotes
# ---
# Список папок ['MyRepository']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/IDE/.git/refs/remotes/MyRepository
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.git/refs/remotes/MyRepository
# ---
# Папок нет
# ---
# Список файлов ['master', 'main']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/refs/remotes/MyRepository/master
# Файл  /Users/serdukovanton/Notebooks/IDE/.git/refs/remotes/MyRepository/main
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/.vscode
# ---
# Папок нет
# ---
# Список файлов ['launch.json']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/.vscode/launch.json
# ===
# Текущая директория /Users/serdukovanton/Notebooks/IDE/Super game
# ---
# Папок нет
# ---
# Список файлов ['game.ipynb']
# ---
# Файл  /Users/serdukovanton/Notebooks/IDE/Super game/game.ipynb
# ===
# Текущая директория /Users/serdukovanton/Notebooks/Old DS
# ---
# Список папок ['.ipynb_checkpoints']
# ---
# Список файлов ['Python-5.ipynb', 'Первый ноутбук.ipynb', 'Python-7.ipynb', 'python-4++.ipynb', 'log.csv', 'Python-4+.ipynb', 'Project-2.ipynb', 'Python-3.ipynb', 'Project-2 Pre.ipynb', 'project-0.ipynb', 'Python-6.ipynb', 'users.csv', 'Python-4.ipynb', 'python.txt', 'sample.csv', 'Stat-1.ipynb', 'Stat-2-3.ipynb', 'Python-2.ipynb', 'Project-1 Anton Serdyukov.ipynb', 'Python-8.ipynb', 'Python-2 webinar.ipynb', 'data_sf.csv', 'Python-10.ipynb', 'movie_bd_v5.csv', 'Python-9.ipynb', 'Stat-4-5.ipynb']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/Old DS/Python-5.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/Первый ноутбук.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/Python-7.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/python-4++.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/log.csv
# Файл  /Users/serdukovanton/Notebooks/Old DS/Python-4+.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/Project-2.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/Python-3.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/Project-2 Pre.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/project-0.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/Python-6.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/users.csv
# Файл  /Users/serdukovanton/Notebooks/Old DS/Python-4.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/python.txt
# Файл  /Users/serdukovanton/Notebooks/Old DS/sample.csv
# Файл  /Users/serdukovanton/Notebooks/Old DS/Stat-1.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/Stat-2-3.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/Python-2.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/Project-1 Anton Serdyukov.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/Python-8.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/Python-2 webinar.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/data_sf.csv
# Файл  /Users/serdukovanton/Notebooks/Old DS/Python-10.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/movie_bd_v5.csv
# Файл  /Users/serdukovanton/Notebooks/Old DS/Python-9.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/Stat-4-5.ipynb
# Папка  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints
# ===
# Текущая директория /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints
# ---
# Папок нет
# ---
# Список файлов ['python-4++-checkpoint.ipynb', 'Project-2-checkpoint.ipynb', 'Python-5-checkpoint.ipynb', 'Первый ноутбук-checkpoint.ipynb', 'Python-4+-checkpoint.ipynb', 'Stat-1-checkpoint.ipynb', 'Stat-4-5-checkpoint.ipynb', 'Python-4-checkpoint.ipynb', 'Python-10-checkpoint.ipynb', 'Python-3-checkpoint.ipynb', 'project-0-checkpoint.ipynb', 'Stat-2-3-checkpoint.ipynb', 'Project-2 Pre-checkpoint.ipynb', 'Python-2 webinar-checkpoint.ipynb', 'Python-8-checkpoint.ipynb', 'Project-1 Anton Serdyukov-checkpoint.ipynb', 'Python-7-checkpoint.ipynb', 'Python-2-checkpoint.ipynb', 'Python-9-checkpoint.ipynb', 'Python-6-checkpoint.ipynb']
# ---
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/python-4++-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Project-2-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-5-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Первый ноутбук-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-4+-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Stat-1-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Stat-4-5-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-4-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-10-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-3-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/project-0-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Stat-2-3-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Project-2 Pre-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-2 webinar-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-8-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Project-1 Anton Serdyukov-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-7-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-2-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-9-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-6-checkpoint.ipynb
# ===
# Текущая директория /Users/serdukovanton/Notebooks/Projects
# ---
# Список папок ['.ipynb_checkpoints']
# ---
# Список файлов ['.DS_Store', 'project-0.ipynb', 'Project-1.ipynb', 'ReadMe', 'Project 2 (EDA).ipynb']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/Projects/.DS_Store
# Файл  /Users/serdukovanton/Notebooks/Projects/project-0.ipynb
# Файл  /Users/serdukovanton/Notebooks/Projects/Project-1.ipynb
# Файл  /Users/serdukovanton/Notebooks/Projects/ReadMe
# Файл  /Users/serdukovanton/Notebooks/Projects/Project 2 (EDA).ipynb
# Папка  /Users/serdukovanton/Notebooks/Projects/.ipynb_checkpoints
# ===
# Текущая директория /Users/serdukovanton/Notebooks/Projects/.ipynb_checkpoints
# ---
# Папок нет
# ---
# Список файлов ['Project 2 (EDA)-checkpoint.ipynb', 'Project-1-checkpoint.ipynb']
# ---
# Файл  /Users/serdukovanton/Notebooks/Projects/.ipynb_checkpoints/Project 2 (EDA)-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Projects/.ipynb_checkpoints/Project-1-checkpoint.ipynb
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS
# ---
# Список папок ['Projects and tasks', '.ipynb_checkpoints', 'data']
# ---
# Список файлов ['.DS_Store', 'Python-11.ipynb', 'untitled.txt', 'Python-13.ipynb', 'Python 1-7.ipynb', 'Python-12.ipynb', 'Python-13p.ipynb', 'Python-10.ipynb', 'Python-9.ipynb']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/New DS/.DS_Store
# Файл  /Users/serdukovanton/Notebooks/New DS/Python-11.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/untitled.txt
# Файл  /Users/serdukovanton/Notebooks/New DS/Python-13.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/Python 1-7.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/Python-12.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/Python-13p.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/Python-10.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/Python-9.ipynb
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks
# Папка  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints
# Папка  /Users/serdukovanton/Notebooks/New DS/data
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks
# ---
# Список папок ['MyRepository']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository
# ---
# Список папок ['.git']
# ---
# Список файлов ['README.md']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/README.md
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git
# ---
# Список папок ['objects', 'info', 'logs', 'hooks', 'refs']
# ---
# Список файлов ['config', 'HEAD', 'description', 'index', 'packed-refs']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/config
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/HEAD
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/description
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/index
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/packed-refs
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/info
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects
# ---
# Список папок ['pack', 'info']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects/pack
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects/info
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects/pack
# ---
# Папок нет
# ---
# Список файлов ['pack-597cf3f9a58496ddd6606768d232d66b13fc93c8.pack', 'pack-597cf3f9a58496ddd6606768d232d66b13fc93c8.idx']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects/pack/pack-597cf3f9a58496ddd6606768d232d66b13fc93c8.pack
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects/pack/pack-597cf3f9a58496ddd6606768d232d66b13fc93c8.idx
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects/info
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/info
# ---
# Папок нет
# ---
# Список файлов ['exclude']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/info/exclude
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs
# ---
# Список папок ['refs']
# ---
# Список файлов ['HEAD']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/HEAD
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs
# ---
# Список папок ['heads', 'remotes']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/heads
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/remotes
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/heads
# ---
# Папок нет
# ---
# Список файлов ['main']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/heads/main
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/remotes
# ---
# Список папок ['origin']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/remotes/origin
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/remotes/origin
# ---
# Папок нет
# ---
# Список файлов ['HEAD']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/remotes/origin/HEAD
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks
# ---
# Папок нет
# ---
# Список файлов ['commit-msg.sample', 'pre-rebase.sample', 'pre-commit.sample', 'applypatch-msg.sample', 'fsmonitor-watchman.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'post-update.sample', 'pre-merge-commit.sample', 'pre-applypatch.sample', 'pre-push.sample', 'update.sample', 'push-to-checkout.sample']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/commit-msg.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/pre-rebase.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/pre-commit.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/applypatch-msg.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/fsmonitor-watchman.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/pre-receive.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/prepare-commit-msg.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/post-update.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/pre-merge-commit.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/pre-applypatch.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/pre-push.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/update.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/push-to-checkout.sample
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs
# ---
# Список папок ['heads', 'tags', 'remotes']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/heads
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/tags
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/remotes
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/heads
# ---
# Папок нет
# ---
# Список файлов ['main']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/heads/main
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/tags
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/remotes
# ---
# Список папок ['origin']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/remotes/origin
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/remotes/origin
# ---
# Папок нет
# ---
# Список файлов ['HEAD']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/remotes/origin/HEAD
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints
# ---
# Папок нет
# ---
# Список файлов ['Python-11-checkpoint.ipynb', 'Python-10-checkpoint.ipynb', 'Python-13p-checkpoint.ipynb', 'Python 1-7-checkpoint.ipynb', 'Python-13-checkpoint.ipynb', 'Python-9-checkpoint.ipynb', 'Python-12-checkpoint.ipynb']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python-11-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python-10-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python-13p-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python 1-7-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python-13-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python-9-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python-12-checkpoint.ipynb
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/data
# ---
# Папок нет
# ---
# ...
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-10-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-3-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/project-0-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Stat-2-3-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Project-2 Pre-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-2 webinar-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-8-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Project-1 Anton Serdyukov-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-7-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-2-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-9-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Old DS/.ipynb_checkpoints/Python-6-checkpoint.ipynb
# ===
# Текущая директория /Users/serdukovanton/Notebooks/Projects
# ---
# Список папок ['.ipynb_checkpoints']
# ---
# Список файлов ['.DS_Store', 'project-0.ipynb', 'Project-1.ipynb', 'ReadMe', 'Project 2 (EDA).ipynb']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/Projects/.DS_Store
# Файл  /Users/serdukovanton/Notebooks/Projects/project-0.ipynb
# Файл  /Users/serdukovanton/Notebooks/Projects/Project-1.ipynb
# Файл  /Users/serdukovanton/Notebooks/Projects/ReadMe
# Файл  /Users/serdukovanton/Notebooks/Projects/Project 2 (EDA).ipynb
# Папка  /Users/serdukovanton/Notebooks/Projects/.ipynb_checkpoints
# ===
# Текущая директория /Users/serdukovanton/Notebooks/Projects/.ipynb_checkpoints
# ---
# Папок нет
# ---
# Список файлов ['Project 2 (EDA)-checkpoint.ipynb', 'Project-1-checkpoint.ipynb']
# ---
# Файл  /Users/serdukovanton/Notebooks/Projects/.ipynb_checkpoints/Project 2 (EDA)-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/Projects/.ipynb_checkpoints/Project-1-checkpoint.ipynb
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS
# ---
# Список папок ['Projects and tasks', '.ipynb_checkpoints', 'data']
# ---
# Список файлов ['.DS_Store', 'Python-11.ipynb', 'untitled.txt', 'Python-13.ipynb', 'Python 1-7.ipynb', 'Python-12.ipynb', 'Python-13p.ipynb', 'Python-10.ipynb', 'Python-9.ipynb']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/New DS/.DS_Store
# Файл  /Users/serdukovanton/Notebooks/New DS/Python-11.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/untitled.txt
# Файл  /Users/serdukovanton/Notebooks/New DS/Python-13.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/Python 1-7.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/Python-12.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/Python-13p.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/Python-10.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/Python-9.ipynb
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks
# Папка  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints
# Папка  /Users/serdukovanton/Notebooks/New DS/data
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks
# ---
# Список папок ['MyRepository']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository
# ---
# Список папок ['.git']
# ---
# Список файлов ['README.md']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/README.md
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git
# ---
# Список папок ['objects', 'info', 'logs', 'hooks', 'refs']
# ---
# Список файлов ['config', 'HEAD', 'description', 'index', 'packed-refs']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/config
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/HEAD
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/description
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/index
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/packed-refs
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/info
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects
# ---
# Список папок ['pack', 'info']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects/pack
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects/info
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects/pack
# ---
# Папок нет
# ---
# Список файлов ['pack-597cf3f9a58496ddd6606768d232d66b13fc93c8.pack', 'pack-597cf3f9a58496ddd6606768d232d66b13fc93c8.idx']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects/pack/pack-597cf3f9a58496ddd6606768d232d66b13fc93c8.pack
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects/pack/pack-597cf3f9a58496ddd6606768d232d66b13fc93c8.idx
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/objects/info
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/info
# ---
# Папок нет
# ---
# Список файлов ['exclude']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/info/exclude
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs
# ---
# Список папок ['refs']
# ---
# Список файлов ['HEAD']
# ---
# Все пути:
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/HEAD
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs
# ---
# Список папок ['heads', 'remotes']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/heads
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/remotes
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/heads
# ---
# Папок нет
# ---
# Список файлов ['main']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/heads/main
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/remotes
# ---
# Список папок ['origin']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/remotes/origin
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/remotes/origin
# ---
# Папок нет
# ---
# Список файлов ['HEAD']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/logs/refs/remotes/origin/HEAD
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks
# ---
# Папок нет
# ---
# Список файлов ['commit-msg.sample', 'pre-rebase.sample', 'pre-commit.sample', 'applypatch-msg.sample', 'fsmonitor-watchman.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'post-update.sample', 'pre-merge-commit.sample', 'pre-applypatch.sample', 'pre-push.sample', 'update.sample', 'push-to-checkout.sample']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/commit-msg.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/pre-rebase.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/pre-commit.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/applypatch-msg.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/fsmonitor-watchman.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/pre-receive.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/prepare-commit-msg.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/post-update.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/pre-merge-commit.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/pre-applypatch.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/pre-push.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/update.sample
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/hooks/push-to-checkout.sample
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs
# ---
# Список папок ['heads', 'tags', 'remotes']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/heads
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/tags
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/remotes
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/heads
# ---
# Папок нет
# ---
# Список файлов ['main']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/heads/main
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/tags
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/remotes
# ---
# Список папок ['origin']
# ---
# Файлов нет
# ---
# Папка  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/remotes/origin
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/remotes/origin
# ---
# Папок нет
# ---
# Список файлов ['HEAD']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/Projects and tasks/MyRepository/.git/refs/remotes/origin/HEAD
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints
# ---
# Папок нет
# ---
# Список файлов ['Python-11-checkpoint.ipynb', 'Python-10-checkpoint.ipynb', 'Python-13p-checkpoint.ipynb', 'Python 1-7-checkpoint.ipynb', 'Python-13-checkpoint.ipynb', 'Python-9-checkpoint.ipynb', 'Python-12-checkpoint.ipynb']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python-11-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python-10-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python-13p-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python 1-7-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python-13-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python-9-checkpoint.ipynb
# Файл  /Users/serdukovanton/Notebooks/New DS/.ipynb_checkpoints/Python-12-checkpoint.ipynb
# ===
# Текущая директория /Users/serdukovanton/Notebooks/New DS/data
# ---
# Папок нет
# ---
# Список файлов ['Video_Games_Sales.csv', 'melb_data_fe.csv', 'products.csv', 'covid_data.csv', 'orders.csv', '.DS_Store', 'character-deaths.csv', 'countries.csv', 'country_vaccinations.csv', 'ae_com.csv', 'hankypanky_com.csv', 'calvinklein_com.csv', 'macys_com.csv', 'battles.csv', 'ratings_movies.csv', 'amazon_com.csv', 'melb_data.csv', 'ufo.csv', 'citibike-tripdata.csv', 'ratings1.csv', 'btemptd_com.csv', 'ratings2.csv', 'students_performance.csv', 'character-predictions.csv', 'dates.csv', 'movies.csv', 'us_topshop_com.csv', 'biden_trump_tweets.csv', 'shop_nordstrom_com.csv', 'victoriassecret_com.csv', 'melb_data-2.csv', 'churn.csv']
# ---
# Файл  /Users/serdukovanton/Notebooks/New DS/data/Video_Games_Sales.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/melb_data_fe.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/products.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/covid_data.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/orders.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/.DS_Store
# Файл  /Users/serdukovanton/Notebooks/New DS/data/character-deaths.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/countries.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/country_vaccinations.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/ae_com.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/hankypanky_com.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/calvinklein_com.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/macys_com.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/battles.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/ratings_movies.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/amazon_com.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/melb_data.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/ufo.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/citibike-tripdata.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/ratings1.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/btemptd_com.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/ratings2.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/students_performance.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/character-predictions.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/dates.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/movies.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/us_topshop_com.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/biden_trump_tweets.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/shop_nordstrom_com.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/victoriassecret_com.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/melb_data-2.csv
# Файл  /Users/serdukovanton/Notebooks/New DS/data/churn.csv
# ===
# Текущая директория /Users/serdukovanton/Notebooks/.ipynb_checkpoints
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория /Users/serdukovanton/Notebooks/data
# ---
# Папок нет
# ---
# Список файлов ['ratings_8.txt', '.DS_Store', 'ratings_9.txt', 'ratings_10.txt', 'cacao_flavors.csv', 'tips.csv', 'stud_math.csv', 'ratings_7.txt', 'ratings_6.txt', 'ratings_4.txt', 'ratings_5.txt', 'ratings_1.txt', 'ratings_2.txt', 'ratings_3.txt']
# ---
# Файл  /Users/serdukovanton/Notebooks/data/ratings_8.txt
# Файл  /Users/serdukovanton/Notebooks/data/.DS_Store
# Файл  /Users/serdukovanton/Notebooks/data/ratings_9.txt
# Файл  /Users/serdukovanton/Notebooks/data/ratings_10.txt
# Файл  /Users/serdukovanton/Notebooks/data/cacao_flavors.csv
# Файл  /Users/serdukovanton/Notebooks/data/tips.csv
# Файл  /Users/serdukovanton/Notebooks/data/stud_math.csv
# Файл  /Users/serdukovanton/Notebooks/data/ratings_7.txt
# Файл  /Users/serdukovanton/Notebooks/data/ratings_6.txt
# Файл  /Users/serdukovanton/Notebooks/data/ratings_4.txt
# Файл  /Users/serdukovanton/Notebooks/data/ratings_5.txt
# Файл  /Users/serdukovanton/Notebooks/data/ratings_1.txt
# Файл  /Users/serdukovanton/Notebooks/data/ratings_2.txt
# Файл  /Users/serdukovanton/Notebooks/data/ratings_3.txt
# ===
# Текущая директория /Users/serdukovanton/Notebooks/Super game
# ---
# Папок нет
# ---
# Список файлов ['game.ipynb']
# ---
# Файл  /Users/serdukovanton/Notebooks/Super game/game.ipynb
# ===

# %%
f = open('IDE/test.txt', 'w', encoding='utf8')

# Запишем в файл строку
f.write("This is a test string\n")
f.write("This is a new string\n")
f.close()
f = open('IDE/test.txt', 'r', encoding='utf8')
print(f.read(10))
f.flush()
f.close()
# Out:
# This is a

# %%
f = open('IDE/test.txt', 'a', encoding='utf8') # открываем файл на дозапись

sequence = ["other string\n", "123\n", "test test\n"]
f.writelines(sequence) # берет строки из sequence и записывает в файл (без переносов)

f.close()

# %%
f = open('IDE/test.txt', 'r', encoding='utf8')
#print(f.readlines()) # считывает все строки в список и возвращает список

print(f.readline()) # This is a test string
print(f.read(4)) # This
print(f.readline()) # is a new string

f.close()
# Out:
# This is a test string
#
# This
#  is a new string

# %%
f = open('IDE/test.txt', 'r', encoding='utf8')
for line in f:
    print(line, end='')
f.close()
# Out:
# This is a test string
# This is a new string
# other string
# 123
# test test

# %%
f = open('IDE/test.txt', 'w', encoding='utf8')

with open("IDE/test.txt", 'rb') as f:
    a = f.read(10)
    b = f.read(23)

# %%
f = open('IDE/input.txt', 'w', encoding='utf8')
f.write("This is a test string\n")
f.write("This is a new string\n")
f.close()

with open("IDE/input.txt", "r") as input_file:
    with open("IDE/output.txt", "w") as output_file:
        for line in input_file:
            output_file.write(line + '||' + output_file.name)

# %%
filename = 'numbers.txt'
output = 'output.txt'

with open(filename) as f:
    min_ = max_ = float(f.readline())  # считали первое число
    for line in f:
        num =  float(line)
        if num > max_:
            max_ = num
        elif num < min_:
            min_ = num

    sum_ = min_ + max_

with open(output, 'w') as f:
    f.write(str(sum_))
    f.write('\n')

# %%
count = 0
for line in open("input.txt"):
    points = int(line.split()[-1])
    if points < 3:
        count += 1

# %%
# реверсирование строк
with open("input.txt", "r") as input_file:
    with open("output.txt", "w") as output_file:
        for line in reversed(input_file.readlines()):
            output_file.write(line)

# %%
class ParentException(Exception):
    def __init__(self, message, error):  # допишем к нашему пустому классу конструктор, который будет печатать дополнительно в консоль информацию об ошибке.
        super().__init__(message)  # помним про вызов конструктора родительского класса
        print(f"Errors: {error}")  # печатаем ошибку

 
class ChildException(ParentException): # создаём пустой класс исключения-потомка, наследуемся от ParentException
    def __init__(self, message, error):
        super().__init__(message, error)
 
 
try:
    raise ChildException("My Message", "My error")  # поднимаем исключение-потомок, передаём дополнительный аргумент
except ParentException as e:
    print(e)  # выводим информацию об исключении
# Out:
# Errors: My error
# My Message

# %%
class NonPositiveDigitException(ValueError):
    pass
 
class Square:
    def __init__(self, a):
        if a <= 0:
            raise NonPositiveDigitException('Неправильно указана сторона квадрата')
